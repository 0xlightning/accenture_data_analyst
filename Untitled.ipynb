# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('../Reactions-Copy1.xlsx')
df
# Out:
#        Unnamed: 0                            Content ID Reaction Type  \
# 0               1  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1               2  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2               3  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 3               4  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 4               5  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
# ...           ...                                   ...           ...
# 24568       25548  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike
# 24569       25549  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued
# 24570       25550  75d6b589-7fae-4a6d-b0d0-752845150e56    interested
# 24571       25551  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 24572       25552  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish
#
#                  Datetime Content Type    Category Sentiment  Score
# ...

# %%
df['Category'] = df['Category'].str.lower()

# %%
total_scores = df.groupby('Category')['Score'].sum()
total_scores
# Out:
# Category
# animals            74965
# cooking            64756
# culture            66579
# dogs               52511
# education          57436
# fitness            55323
# food               66676
# healthy eating     69339
# public speaking    49264
# science            71168
# soccer             57783
# studying           54269
# technology         68738
# tennis             50339
# travel             64880
# veganism           49619
# Name: Score, dtype: int64

# %%
top_five_categories = total_scores.sort_values(ascending=False).head(5)[::-1]
top_five_categories
# Out:
# Category
# food              66676
# technology        68738
# healthy eating    69339
# science           71168
# animals           74965
# Name: Score, dtype: int64

# %%
plt.title('Top 5 Category by Aggregate Score "Popularity"')
plt.xlabel('Aggregate Score')
plt.ylabel('CATEGORIES')
plt.barh(top_five_categories.index, top_five_categories)
plt.xlim(60000, 78000) ;

# %%
plt.title('Popularity percentage share for Top 5 Categories')
plt.pie(top_five_categories, labels=top_five_categories.index,autopct="%0.1f%%", startangle=180, shadow=True, explode=[0.04,0,0,0.06,0.1]);
